# %%
import matplotlib.pyplot as plt
import tensorflow as tf
# %matplotlib inline

# %%
####### >>>>>填写<<<<<   设置你想要的真实斜率和截距， 以及数据点(50-200) >>>>>填写<<<<< ############
true_w = 2
true_b = 15
num_samples = 150

############################################################################################


# 初始化随机数据
X = tf.random.normal(shape=[num_samples, 1]).numpy()#num_samples行1列的随机数
noise = tf.random.normal(shape=[num_samples, 1]).numpy()
#print(noise.shape)
####### >>>>>填写<<<<< 在下述函数尾端，添加噪音项, 注意删除下划线 >>>>>填写<<<<<  ################################
y = X * true_w + true_b  + noise
#######################################

plt.scatter(X, y)

# %%
W = tf.Variable(tf.random.uniform([1]))  # 随机初始化参数
b = tf.Variable(tf.random.uniform([1]))
print(tf.random.uniform([1]))

# >>>>>填写<<<<<  定义一个随机一元一次线性函数  y = W * x + b   >>>>>填写<<<<<  ##
# 思考 这里的x为什么是小写？ #
def random_line(x):
 
    y = W * x + b
    return y
# Out:
# tf.Tensor([0.51413345], shape=(1,), dtype=float32)

# %%
plt.scatter(X, y)
plt.plot(X, random_line(X), c='r')

# %%
def loss_fn( x, y):
    y_ = random_line(x)
    return tf.reduce_mean(tf.square(y_ - y))

# %%
### >>>>>填写<<<<< 通过改变epochs 的值，推荐起始10， 和learning rate 学习率 推荐0.1起始 观察梯度下降学习的线性函数w b的值，以及loss函数的变化>>>>>填写<<<<<  ######

EPOCHS = 30
LEARNING_RATE = 0.1
#######################################################################################################################################



for epoch in range(EPOCHS):  # 迭代次数
    with tf.GradientTape() as tape:  # 追踪梯度
        loss = loss_fn(X, y)  # 计算损失
    dW, db = tape.gradient(loss, [W, b])  # 计算梯度
    print('\n',dW,'*****')
    W.assign_sub(LEARNING_RATE * dW)  # 更新梯度
    b.assign_sub(LEARNING_RATE * db)
    plt.plot(X, random_line(X), c='r')
    # 输出计算过程
    print('Epoch [{}/{}], loss [{:.3f}], W is [{:.3f}], b is [{:.3f}]'.format(epoch, EPOCHS, loss,
                                                                     float(W.numpy()),
                                                                     float(b.numpy())))
plt.scatter(X, y)
#plt.plot(X, random_line(X), c='r')
# Out:
#  tf.Tensor([-2.5403676], shape=(1,), dtype=float32) *****
# Epoch [0/30], loss [210.528], W is [0.474], b is [3.419]
#
#  tf.Tensor([-2.2412608], shape=(1,), dtype=float32) *****
# Epoch [1/30], loss [135.564], W is [0.698], b is [5.720]
#
#  tf.Tensor([-1.9633594], shape=(1,), dtype=float32) *****
# Epoch [2/30], loss [87.440], W is [0.895], b is [7.562]
#
#  tf.Tensor([-1.7095635], shape=(1,), dtype=float32) *****
# Epoch [3/30], loss [56.536], W is [1.066], b is [9.036]
#
#  tf.Tensor([-1.4808726], shape=(1,), dtype=float32) *****
# Epoch [4/30], loss [36.685], W is [1.214], b is [10.217]
#
#  tf.Tensor([-1.277009], shape=(1,), dtype=float32) *****
# Epoch [5/30], loss [23.928], W is [1.342], b is [11.163]
#
#  tf.Tensor([-1.0968719], shape=(1,), dtype=float32) *****
# Epoch [6/30], loss [15.727], W is [1.451], b is [11.920]
#
#  tf.Tensor([-0.9388665], shape=(1,), dtype=float32) *****
# Epoch [7/30], loss [10.453], W is [1.545], b is [12.526]
#
#  tf.Tensor([-0.80113363], shape=(1,), dtype=float32) *****
# Epoch [8/30], loss [7.061], W is [1.625], b is [13.012]
#
#  tf.Tensor([-0.68171203], shape=(1,), dtype=float32) *****
# Epoch [9/30], loss [4.878], W is [1.693], b is [13.401]
#
#  tf.Tensor([-0.57864475], shape=(1,), dtype=float32) *****
# Epoch [10/30], loss [3.472], W is [1.751], b is [13.712]
#
#  tf.Tensor([-0.4900518], shape=(1,), dtype=float32) *****
# Epoch [11/30], loss [2.567], W is [1.800], b is [13.962]
#
#  tf.Tensor([-0.4141717], shape=(1,), dtype=float32) *****
# Epoch [12/30], loss [1.983], W is [1.842], b is [14.162]
#
#  tf.Tensor([-0.3493858], shape=(1,), dtype=float32) *****
# Epoch [13/30], loss [1.607], W is [1.877], b is [14.322]
#
#  tf.Tensor([-0.29422852], shape=(1,), dtype=float32) *****
# Epoch [14/30], loss [1.365], W is [1.906], b is [14.451]
#
#  tf.Tensor([-0.24738872], shape=(1,), dtype=float32) *****
# Epoch [15/30], loss [1.208], W is [1.931], b is [14.554]
#
#  tf.Tensor([-0.20770335], shape=(1,), dtype=float32) *****
# Epoch [16/30], loss [1.107], W is [1.952], b is [14.636]
#
#  tf.Tensor([-0.17415015], shape=(1,), dtype=float32) *****
# Epoch [17/30], loss [1.042], W is [1.969], b is [14.702]
#
#  tf.Tensor([-0.14583543], shape=(1,), dtype=float32) *****
# Epoch [18/30], loss [1.000], W is [1.984], b is [14.755]
#
#  tf.Tensor([-0.12198301], shape=(1,), dtype=float32) *****
# Epoch [19/30], loss [0.972], W is [1.996], b is [14.798]
#
#  tf.Tensor([-0.1019217], shape=(1,), dtype=float32) *****
# Epoch [20/30], loss [0.955], W is [2.006], b is [14.832]
#
#  tf.Tensor([-0.08507418], shape=(1,), dtype=float32) *****
# Epoch [21/30], loss [0.943], W is [2.014], b is [14.859]
#
#  tf.Tensor([-0.07094441], shape=(1,), dtype=float32) *****
# Epoch [22/30], loss [0.936], W is [2.022], b is [14.881]
#
#  tf.Tensor([-0.05910932], shape=(1,), dtype=float32) *****
# Epoch [23/30], loss [0.931], W is [2.027], b is [14.898]
#
#  tf.Tensor([-0.04920809], shape=(1,), dtype=float32) *****
# Epoch [24/30], loss [0.928], W is [2.032], b is [14.912]
#
#  tf.Tensor([-0.04093342], shape=(1,), dtype=float32) *****
# Epoch [25/30], loss [0.926], W is [2.036], b is [14.924]
#
#  tf.Tensor([-0.0340247], shape=(1,), dtype=float32) *****
# Epoch [26/30], loss [0.925], W is [2.040], b is [14.933]
#
#  tf.Tensor([-0.02826294], shape=(1,), dtype=float32) *****
# Epoch [27/30], loss [0.924], W is [2.043], b is [14.940]
#
#  tf.Tensor([-0.02346131], shape=(1,), dtype=float32) *****
# Epoch [28/30], loss [0.924], W is [2.045], b is [14.946]
#
#  tf.Tensor([-0.01946367], shape=(1,), dtype=float32) *****
# Epoch [29/30], loss [0.923], W is [2.047], b is [14.951]

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-c1f8158315d5> in <module>
# ----> 1 print(tape)
#
# NameError: name 'tape' is not defined
